# %% [markdown]
# # Array creation & dtype

# %% [markdown]
# ## np.array
#
# ### Problem
# We need: Create array from list
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.array

# %%
import numpy as np
arr = np.array([1,2,3], dtype=float)

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## np.arange
#
# ### Problem
# We need: Range-based array
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.arange

# %%
import numpy as np
arr = np.arange(0,10,2)
print(arr)
# Out:
# [0 2 4 6 8]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## np.zeros / ones
#
# ### Problem
# We need: Initialize arrays
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.zeros / ones

# %%
import numpy as np
arr = np.zeros((2,3))

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# # Shape, reshape & memory

# %% [markdown]
# ## shape
#
# ### Problem
# We need: Understand dimensions
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# shape

# %%
import numpy as np
arr = np.arange(6).reshape(2,3); print(arr.shape)
# Out:
# (2, 3)

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## reshape
#
# ### Problem
# We need: Change view
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# reshape

# %%
import numpy as np
arr = np.arange(6); arr2 = arr.reshape(2,3)

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## copy
#
# ### Problem
# We need: Memory duplication
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# copy

# %%
import numpy as np
a = np.array([1,2]); b=a; c=a.copy()

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ### Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# # Indexing & slicing

# %% [markdown]
# ## basic slicing
#
# ### Problem
# We need: View vs copy
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# basic slicing

# %%
import numpy as np
arr = np.arange(6).reshape(2,3); res = arr[:,1:]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ### DSolution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## boolean indexing
#
# ### Problem
# We need: Filtering
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# boolean indexing

# %%
import numpy as np
arr = np.array([1,3,0]); res = arr[arr>1]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## fancy indexing
#
# ### Problem
# We need: Index arrays
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# fancy indexing

# %%
import numpy as np
arr = np.array([2,4,6,8]); res = arr[[0,2,3]]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# # Broadcasting

# %% [markdown]
# ## elementwise ops
#
# ### Problem
# We need: Broadcast logic
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# elementwise ops

# %%
import numpy as np
a = np.array([1,2]); b=np.array([3,4]); print(a+b)
# Out:
# [4 6]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## np.newaxis
#
# ### Problem
# We need: Control broadcasting
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.newaxis

# %%
import numpy as np
a = np.array([1,2,3]); print(a[:,np.newaxis].shape)
# Out:
# (3, 1)

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# # Math operations

# %% [markdown]
# ## sum/mean
#
# ### Problem
# We need: Aggregations
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# sum/mean

# %%
import numpy as np
arr = np.array([1,2,3]); print(arr.mean())
# Out:
# 2.0

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## np.sqrt
#
# ### Problem
# We need: Vectorized functions
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.sqrt

# %%
import numpy as np
arr = np.array([1,4,9]); print(np.sqrt(arr))
# Out:
# [1. 2. 3.]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# # Linear algebra

# %% [markdown]
# ## np.dot
#
# ### Problem
# We need: Dot product
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.dot

# %%
import numpy as np
a=np.array([1,2,3]); b=np.array([0,1,1]); print(np.dot(a,b))
# Out:
# 5

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ###  Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory

# %% [markdown]
# ## np.linalg.inv
#
# ### Problem
# We need: Matrix inverse
#
# ### Manual Solution
# Python loops / lists
#
# ### Why Impractical
# Slow, not vectorized
#
# ### NumPy Abstraction
# np.linalg.inv

# %%
import numpy as np
a=np.array([[1,2],[3,4]]); print(np.linalg.inv(a))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# ### Exercise
# 1. Modify the example
# 2. Predict output shape
# 3. Decide: view or copy?

# %% [markdown]
# ### Solution
#
# - Shape depends on operation
# - View vs Copy:
#     - slicing → view
#     - fancy indexing → copy
#     - reshape → view if possible
# - Key insight:
#     NumPy avoids copying whenever possible by reusing memory
